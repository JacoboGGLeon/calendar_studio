# %% [markdown]
# # Calendar Studio 2026 Launcher (End to End)
#
# Este notebook permite inicializar y ejecutar de principio a fin **Calendar Studio**. Puede ser ejecutado en entornos locales (VS Code, JupyterLab) o en la nube (Google Colab).
#
# Al ejecutar el entorno E2E, se descargará el proyecto directamente desde GitHub, se prepararán las dependencias y se levantará el servidor web.

# %%
# 1. Clonar el repositorio de Calendar Studio
# !git clone https://github.com/JacoboGGLeon/calendar_studio.git
# %cd calendar_studio

# %%
# 2. Instalar las dependencias
# !pip install -r requirements.txt

# %%
# 3. Ejecutar el Servidor Streamlit en segundo plano
# En Colab o entornos headless puedes usar localtunnel o ngrok. 
# Para correr en ambiente local como Jupyter, ejecuta el siquiente comando bloqueante:

# !streamlit run streamlit_app.py

# %% [markdown]
# ---
# ### Acceso en la Nube (Google Colab)
# Si estás usando un entorno Colab, usar el comando anterior bloqueará la celda sin poder acceder a `http://localhost:8501`.
#
# Para esos casos, descomenta y ejecuta la siguiente celda en lugar de la anterior para obtener un tunel seguro público:

# %%
# !npm install localtunnel
# print('Tu Tunnel Password saldrá aquí abajo. Haz clic en el link final de localtunnel')
# !urllib -qO - https://loca.lt/mytunnelpassword
# !streamlit run streamlit_app.py & npx localtunnel --port 8501
