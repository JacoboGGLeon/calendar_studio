# %% [markdown]
# # Calendar Studio 2026 Launcher
#
# Este notebook permite a los Científicos de Datos ejecutar y probar la interfaz de **Calendar Studio** directamente desde su entorno exploratorio (Jupyter/Colab).
#
# ### Instrucciones
# 1. Asegúrate de tener instaladas las dependencias requeridas (la celda de abajo lo hace automáticamente).
# 2. Ejecuta la última celda de código para levantar el servidor web de Streamlit.
# 3. Haz clic en el enlace local (usualmente `http://localhost:8501`) para iterar y pintar tu calendario.
# 4. Desde la Interfaz Gráfica podrás exportar los datos calculados limpios en `.csv` para alimentar tus modelos de ML o Pipelines.

# %%
# Instalar dependencias si no están presentes
# !pip install -r requirements.txt

# %%
# Levantar el servidor de la aplicación
# !streamlit run streamlit_app.py

# %% [markdown]
# ---
# *(Nota: Al ejecutar Streamlit en Jupyter, la celda se quedará ejecutándose continuamente [con un `*`]. Para detener el servidor Web y seguir usando el notebook para otras cosas, detén manualmente la ejecución de esa celda).*
